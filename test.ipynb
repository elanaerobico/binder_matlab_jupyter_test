% %% [markdown]
% ---
% title: "Jupyter Octave"
% format:
%   html:
%     code-fold: true
% jupyter: octave_kernel
% ---

% %% [markdown]
% Generación de números aleatorios
%
% ```{octave_kernel}
% a=rand(1,30);
% plot(a,'-r')
%
% ```

% %%
a=rand(1,30);
plot(a,'-r')
